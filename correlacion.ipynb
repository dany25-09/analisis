# %% [markdown]
# ![Banner-Introducci-n.png](https://i.postimg.cc/VkCcqsvv/Banner-Introducci-n.png)

# %% [markdown]
# # Introducción a ciencia de datos
#
#
# ## L1: Pruebas de correlación de Pearson y Spearman
#
# De acuerdo con el caso de uso del sector **retail**  se van a desarrollar en los temas vistos en las infografías y videos anteriores
#
# ### Objetivos
# 1. Identificar los diferentes tipos de correlación
# 2. Usar las herramientas brindadas por python para el cálculo de estas medidas
# 3. Probar las hipótesis propuestas con los temas vistos

# %% [markdown]
# **Autor:** David Ocampo
#
# d.ocampo@uniandes.edu.co

# %% [markdown]
# ### 1. Contexto del caso
# La organización quiere investigar la relación que tienen los precios con los datos relacionados con los envíos, esto debido a que existe una gran demanda de pedidos y se quiere conocer cómo generar estrategias comerciales relacionadas con los pedidos, que permitan ofrecerle mejores precios a los clientes desde el origen del incremento en la venta final(incluído, el envío). Se le ha pedido al área de Ciencia de Datos identificar posibles patrones para encontrar dónde focalizar la estrategia correcta

# %% [markdown]
# ### 2. Importación de librerías y archivos
# En las siguientes líneas de código se importaran los materiales de trabajo necesarios para desarrollar el caso de uso, en esto se incluyen las *librerías y los datos*

# %%
# Importar las librerías necesarias según el análisis que se vaya a realizar
# Librería para comando de sistema
import os
# Librería para manejo de datos
import pandas as pd
#Librería para gráficos
import matplotlib.pyplot as plt

# %%
# cargar los datos en csv
data= pd.read_csv('Ordenes_productos_C1_M3.csv', sep=';',encoding='latin-1')

# %% [markdown]
# Es importante tener en cuenta la visualización de los datos porque además de contexto se puede entender mucho mejor de qué se está hablando y qué tipos de datos se han cargado desde la máquina

# %%
#visualizar los primeros registros
data.head(5)
# Out:
#       orden_id order_item_id producto_id vendedor_id fecha_envio_limite  \
# 0  107500PO59A             A        PO59      VE5389   07/04/2018 18:12
# 1   37493PS22B             B        PS22      VE1558   20/10/2017 09:07
# 2   28050PK20B             B        PK20      VE9159   17/08/2017 08:15
# 3   52187PA10A             A        PA10      VE3159   23/09/2017 23:27
# 4   84639PR12A             A        PR12      VE5090   07/01/2018 11:50
#
#    precio  valor_flete  codigo_postal_vendedor ciudad_vendedor  \
# 0  271.86        30.72                   70001       Sincelejo
# 1  115.73         4.68                   66001         Pereira
# 2  432.99        82.70                    8001    Barranquilla
# 3  108.38        35.39                   18001       Florencia
# 4   51.50        11.10                   11001     Bogota d.c.
#
#   departamento_vendedor nombre_categoria_producto  longitud_nombre_producto  \
# 0                 Sucre    Productos ecoamigables                         6
# 1             Risaralda                Carnicería                        10
# 2             Atlantico                  Deportes                        25
# 3               Caqueta         Electrodomésticos                        10
# 4           Bogota d.c.         Frutas y verduras                        23
#
#    longitud_descripcion_producto  cantidad_fotos_producto  peso_g_producto  \
# 0                              7                       27             2486
# 1                             31                       20              256
# 2                              5                        4             5270
# 3                              1                        6              734
# 4                             16                       35              884
#
#    longitud_cm_producto  altura_cm_producto  ancho_cm_producto
# 0                    17                  11                 14
# 1                    43                   2                 21
# 2                     9                  27                 29
# 3                    46                  48                 22
# 4                    45                  26                 18

# %% [markdown]
# Los tipos de datos nos van a ayudar a entender qué análisis se pueden realizar con cada variable para su correcta interpretación

# %%
# Revisar los tipos de data en el archivo
data.dtypes
# Out:
# orden_id                          object
# order_item_id                     object
# producto_id                       object
# vendedor_id                       object
# fecha_envio_limite                object
# precio                           float64
# valor_flete                      float64
# codigo_postal_vendedor             int64
# ciudad_vendedor                   object
# departamento_vendedor             object
# nombre_categoria_producto         object
# longitud_nombre_producto           int64
# longitud_descripcion_producto      int64
# cantidad_fotos_producto            int64
# peso_g_producto                    int64
# longitud_cm_producto               int64
# altura_cm_producto                 int64
# ancho_cm_producto                  int64
# dtype: object

# %% [markdown]
# ### 3. Correlación de Pearson
# Es una medida de la relación lineal entre dos variables. De manera menos formal, podemos definir el coeficiente de correlación de Pearson como un índice que puede utilizarse para medir el grado de relación de dos variables siempre y cuando ambas sean cuantitativas y continuas.
#
# **Hipótesis:** La organización está interesada en investigar si el precio de los productos influye en el peso de los mismos

# %%
# Revisar la dispersión de los datos de precio y peso
plt.scatter(data['precio'], data['peso_g_producto']);

# %%
# Revisar la dispersión de los datos de precio y peso
plt.scatter(data['peso_g_producto'], data['valor_flete']);

# %% [markdown]
# En las siguientes líneas de código vamos calcular la correlación lineal que tienen los datos mostrados anteriormente, para así darle una trascendencia más allá de lo gráficamente visto, para esto además, vamos a calcular la correlación con todas las demás variables numéricas que existan

# %%
# Calcular coeficiente de pearson para todos los datos numéricos
data[['precio','valor_flete','peso_g_producto']].corr(method='pearson')
# Out:
#                    precio  valor_flete  peso_g_producto
# precio           1.000000     0.004075         0.000687
# valor_flete      0.004075     1.000000        -0.007394
# peso_g_producto  0.000687    -0.007394         1.000000

# %% [markdown]
# Análisis: Vemos que no existe una relación lineal entre el precio y el peso del producto, tampoco podemos ver esta relación entre el valor del flete y el peso del producto

# %% [markdown]
# ### 4. Correlación de Spearman
#
# En estadística, la correlación de Spearman evalúa la relación monótona entre dos variables continuas u ordinales. En una relación monótona, las variables tienden a cambiar al mismo tiempo, pero no necesariamente a un ritmo constante. El coeficiente de correlación de Spearman se basa en los valores jerarquizados de cada variable y no en los datos sin procesar.
#
# **Hipótesis:** Las medidas de volumen (largo, ancho, alto) están relacionadas con el peso, con esto podríamos establecer si las medidas permiten analizar una relación con el peso del producto

# %%
#Crear medida del volumen y área del producto
#Área del producto
data['area_cm2_producto']=data['longitud_cm_producto']*data['altura_cm_producto']
#Volumen de producto
data['volumen_cm3_producto']=data['longitud_cm_producto']*data['altura_cm_producto']*data['ancho_cm_producto']
data.head()
# Out:
#       orden_id order_item_id producto_id vendedor_id fecha_envio_limite  \
# 0  107500PO59A             A        PO59      VE5389   07/04/2018 18:12
# 1   37493PS22B             B        PS22      VE1558   20/10/2017 09:07
# 2   28050PK20B             B        PK20      VE9159   17/08/2017 08:15
# 3   52187PA10A             A        PA10      VE3159   23/09/2017 23:27
# 4   84639PR12A             A        PR12      VE5090   07/01/2018 11:50
#
#    precio  valor_flete  codigo_postal_vendedor ciudad_vendedor  \
# 0  271.86        30.72                   70001       Sincelejo
# 1  115.73         4.68                   66001         Pereira
# 2  432.99        82.70                    8001    Barranquilla
# 3  108.38        35.39                   18001       Florencia
# 4   51.50        11.10                   11001     Bogota d.c.
#
#   departamento_vendedor nombre_categoria_producto  longitud_nombre_producto  \
# 0                 Sucre    Productos ecoamigables                         6
# 1             Risaralda                Carnicería                        10
# 2             Atlantico                  Deportes                        25
# 3               Caqueta         Electrodomésticos                        10
# 4           Bogota d.c.         Frutas y verduras                        23
#
#    longitud_descripcion_producto  cantidad_fotos_producto  peso_g_producto  \
# 0                              7                       27             2486
# 1                             31                       20              256
# 2                              5                        4             5270
# 3                              1                        6              734
# 4                             16                       35              884
#
#    longitud_cm_producto  altura_cm_producto  ancho_cm_producto  \
# 0                    17                  11                 14
# 1                    43                   2                 21
# 2                     9                  27                 29
# 3                    46                  48                 22
# 4                    45                  26                 18
#
#    area_cm2_producto  volumen_cm3_producto
# 0                187                  2618
# 1                 86                  1806
# 2                243                  7047
# 3               2208                 48576
# 4               1170                 21060

# %%
#graficar el área contra el peso
plt.scatter(data['area_cm2_producto'],data['peso_g_producto'])

# %%
#graficar el volumen contra el peso
plt.scatter(data['volumen_cm3_producto'],data['peso_g_producto'])

# %% [markdown]
# Por último vamos a graficar las relaciones con cada uno de los componentes para el cálculo de estas medidas del producto para así analizar gráficamente las relaciones que existen, además para validar estos análisis gráficos la matriz de correlaciones de spearman

# %%
# graficar las demás relaciones alto, ancho, alto
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(30,10))
fig.suptitle('Relaciones alto, ancho, alto')
ax1.scatter(data['longitud_cm_producto'], data['peso_g_producto'])
ax2.scatter(data['ancho_cm_producto'], data['peso_g_producto'])
ax3.scatter(data['altura_cm_producto'], data['peso_g_producto'])

# %%
# matriz de correlaciones de spearman
corr=data[['longitud_cm_producto','altura_cm_producto',
      'ancho_cm_producto','peso_g_producto',
      'area_cm2_producto','volumen_cm3_producto','precio','valor_flete']].corr(method='spearman')
corr
# Out:
#                       longitud_cm_producto  altura_cm_producto  \
# longitud_cm_producto              1.000000            0.002816
# altura_cm_producto                0.002816            1.000000
# ancho_cm_producto                -0.004389            0.011629
# peso_g_producto                   0.013190            0.015161
# area_cm2_producto                 0.584639            0.753285
# volumen_cm3_producto              0.484020            0.631474
# precio                           -0.007994           -0.003369
# valor_flete                       0.001056           -0.000340
#
#                       ancho_cm_producto  peso_g_producto  area_cm2_producto  \
# longitud_cm_producto          -0.004389         0.013190           0.584639
# altura_cm_producto             0.011629         0.015161           0.753285
# ancho_cm_producto              1.000000         0.014688           0.007347
# peso_g_producto                0.014688         1.000000           0.022410
# area_cm2_producto              0.007347         0.022410           1.000000
# volumen_cm3_producto           0.471033         0.022648           0.838702
# precio                        -0.013001        -0.009197          -0.006044
# valor_flete                    0.003442        -0.003148           0.000411
#
#                       volumen_cm3_producto    precio  valor_flete
# longitud_cm_producto              0.484020 -0.007994     0.001056
# altura_cm_producto                0.631474 -0.003369    -0.000340
# ancho_cm_producto                 0.471033 -0.013001     0.003442
# peso_g_producto                   0.022648 -0.009197    -0.003148
# area_cm2_producto                 0.838702 -0.006044     0.000411
# volumen_cm3_producto              1.000000 -0.012369     0.003331
# precio                           -0.012369  1.000000     0.010807
# valor_flete                       0.003331  0.010807     1.000000

# %%
#Graficar las variables con correlación
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(30,10))
fig.suptitle('Relaciones de correlación')
ax1.scatter(data['longitud_cm_producto'], data['area_cm2_producto'])
ax2.scatter(data['ancho_cm_producto'], data['area_cm2_producto'])
ax3.scatter(data['altura_cm_producto'], data['area_cm2_producto'])

# %% [markdown]
# Análisis: Podemos revisar que en efecto las medidas para calcular el volúmen y el área no están correlacionadas con el peso, esta interpretación nos va a permitir eventualmente buscar descuentos con la mensajería según otras medidas, por ejemplo, en la tabla las correlaciones que existen son entre longitud y altura, podríamos establecer alguna manera de tarificar el envío a través de estas medidas

# %%
#Bonus
#Graficar las correlaciones
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
# #T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col0,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col1,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col2,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col4,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col5,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col7{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col1,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col4{
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col2,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col0,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col0{
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col0,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col2{
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col4,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col0{
#             background-color:  #f0cdbb;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col5{
#             background-color:  #dadce0;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col2,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col2,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col6{
#             background-color:  #4257c9;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col4,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col1{
#             background-color:  #f39778;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col5{
#             background-color:  #f5c1a9;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col0,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col6,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col0,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col1,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col2,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col4,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col5,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col1,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col4,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row6_col7,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col5{
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col5,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col2{
#             background-color:  #d7dce3;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col1,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row7_col2{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col4{
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row3_col5,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col3,#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col3{
#             background-color:  #445acc;
#             color:  #f1f1f1;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row4_col5{
#             background-color:  #e57058;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col0{
#             background-color:  #d9dce1;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col1{
#             background-color:  #f5c2aa;
#             color:  #000000;
#         }#T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row5_col4{
#             background-color:  #e67259;
#             color:  #000000;
#         }</style><table id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >longitud_cm_producto</th>        <th class="col_heading level0 col1" >altura_cm_producto</th>        <th class="col_heading level0 col2" >ancho_cm_producto</th>        <th class="col_heading level0 col3" >peso_g_producto</th>        <th class="col_heading level0 col4" >area_cm2_producto</th>        <th class="col_heading level0 col5" >volumen_cm3_producto</th>        <th class="col_heading level0 col6" >precio</th>        <th class="col_heading level0 col7" >valor_flete</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2level0_row0" class="row_heading level0 row0" >longitud_cm_producto</th>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col0" class="data row0 col0" >1.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col1" class="data row0 col1" >0.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col2" class="data row0 col2" >-0.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col3" class="data row0 col3" >0.01</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col4" class="data row0 col4" >0.58</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col5" class="data row0 col5" >0.48</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col6" class="data row0 col6" >-0.01</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row0_col7" class="data row0 col7" >0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2level0_row1" class="row_heading level0 row1" >altura_cm_producto</th>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col0" class="data row1 col0" >0.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col1" class="data row1 col1" >1.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col2" class="data row1 col2" >0.01</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col3" class="data row1 col3" >0.02</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col4" class="data row1 col4" >0.75</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col5" class="data row1 col5" >0.63</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col6" class="data row1 col6" >-0.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row1_col7" class="data row1 col7" >-0.00</td>
#             </tr>
#             <tr>
#                         <th id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2level0_row2" class="row_heading level0 row2" >ancho_cm_producto</th>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col0" class="data row2 col0" >-0.00</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col1" class="data row2 col1" >0.01</td>
#                         <td id="T_18b3a518_27a2_11ec_8f0f_ed7a0a37bbb2row2_col2" class=

# %% [markdown]
# ![Banner-Introducci-n.png](https://i.postimg.cc/VkCcqsvv/Banner-Introducci-n.png)
